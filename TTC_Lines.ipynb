# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')
import geopandas as gpd

# Replace 'your_file.shp' with the path to your shapefile
shapefile_path = r'C:\Users\amoore\Downloads\GIS_Data_-_Future_Transit_Network_-_2023-05-12\RTP_POINTS.shp'

# Read the shapefile
gdf = gpd.read_file(shapefile_path)

# Convert to a pandas DataFrame if needed (geopandas is a subclass of pandas)
df = gdf.copy()

# Display the DataFrame
#gdf_FILT = gdf[['NAME', 'geometry','TECHNOLOGY','LOCATION_N']]

#df = gdf_FILT.copy()

print(df.head(50))
print(gdf.columns)
# Out:
#                 LOCATION_N       STATUS TECHNOLOGY                    NAME
# 0              Creditstone     Existing        BRT      Highway 7 West BRT  \
# 1                    Keele     Existing        BRT      Highway 7 West BRT
# 2                    Davis  In Delivery        BRT         Yonge North BRT
# 3                    Eagle     Existing        BRT         Yonge North BRT
# 4                   Mulock     Existing        BRT         Yonge North BRT
# 5              19th-Gamble     Existing        BRT         Yonge South BRT
# 6          Major Mackenzie     Existing        BRT         Yonge South BRT
# 7              Elgin Mills     Existing        BRT         Yonge South BRT
# 8                  Bernard     Existing        BRT         Yonge South BRT
# 9             Bantry-Scott     Existing        BRT         Yonge South BRT
# 10          16th-Carrville     Existing        BRT         Yonge South BRT
# 11                Weldrick     Existing        BRT         Yonge South BRT
# 12          Bathurst/Hwy 7     Existing        BRT      Highway 7 West BRT
# 13                Atkinson     Existing        BRT      Highway 7 West BRT
# 14        Disera-Promenade     Existing        BRT      Highway 7 West BRT
# 15                   Taiga     Existing        BRT      Highway 7 West BRT
# 16                Dufferin     Existing        BRT      Highway 7 West BRT
# 17                Commerce     Existing        BRT      Highway 7 West BRT
# 18                  Weston     Existing        BRT      Highway 7 West BRT
# 19             Pine Valley     Existing        BRT      Highway 7 West BRT
# 20            Ansley Grove     Existing        BRT      Highway 7 West BRT
# 21           Wigwoss-Helen     Existing        BRT      Highway 7 West BRT
# 22               Southlake     Existing        BRT         Davis Drive BRT
# 23                    Main     Existing        BRT         Davis Drive BRT
# 24                Longford     Existing        BRT         Davis Drive BRT
# 25             Yonge/Davis     Existing        BRT         Davis Drive BRT
# 26                 Bayview     Existing        BRT      Highway 7 East BRT
# 27                Chalmers     Existing        BRT      Highway 7 East BRT
# 28              Valleymede     Existing        BRT      Highway 7 East BRT
# 29       West Beaver Creek     Existing        BRT      Highway 7 East BRT
# 30                  Leslie     Existing        BRT      Highway 7 East BRT
# 31       East Beaver Creek     Existing        BRT      Highway 7 East BRT
# 32        Allstate Parkway     Existing        BRT      Highway 7 East BRT
# 33                Woodbine     Existing        BRT      Highway 7 East BRT
# 34              Montgomery     Existing        BRT      Highway 7 East BRT
# 35       Town Centre Blvd.     Existing        BRT      Highway 7 East BRT
# 36               Cedarland     Existing        BRT      Highway 7 East BRT
# 37                  Warden     Existing        BRT      Highway 7 East BRT
# 38                  Avenue  In Delivery        LRT  Eglinton Crosstown LRT
# 39             Forest Hill  In Delivery        LRT  Eglinton Crosstown LRT
# 40                 Leaside  In Delivery        LRT  Eglinton Crosstown LRT
# 41                  Sloane  In Delivery        LRT  Eglinton Crosstown LRT
# 42              Birchmount  In Delivery        LRT  Eglinton Crosstown LRT
# 43               Caledonia  In Delivery        LRT  Eglinton Crosstown LRT
# 44                 Chaplin  In Delivery        LRT  Eglinton Crosstown LRT
# 45          Science Centre  In Delivery        LRT  Eglinton Crosstown LRT
# 46                Fairbank  In Delivery        LRT  Eglinton Crosstown LRT
# 47                Eglinton  In Delivery        LRT  Eglinton Crosstown LRT
# 48               Cedarvale  In Delivery        LRT  Eglinton Crosstown LRT
# 49  Aga Khan Park & Museum  In Delivery        LRT  Eglinton Crosstown LRT
#
#                           geometry
# 0   POINT (303369.273 4850639.811)
# 1   POINT (304847.452 4851150.715)
# 2   POINT (306373.949 4879421.963)
# 3    POINT (306550.211 4878383.22)
# 4   POINT (306720.789 4877366.807)
# 5   POINT (309155.249 4863102.939)
# 6    POINT (309846.17 4859036.301)
# 7   POINT (309507.146 4861073.051)
# 8   POINT (309292.147 4862313.255)
# 9   POINT (310315.411 4856271.594)
# 10  POINT (310188.666 4857018.355)
# 11  POINT (309994.462 4858162.578)
# 12  POINT (308470.397 4854683.246)
# 13  POINT (308697.474 4853036.345)
# 14  POINT (308524.454 4852243.657)
# 15  POINT (307933.834 4852069.808)
# 16    POINT (306845.836 4851742.3)
# 17  POINT (302086.978 4850243.838)
# 18  POINT (300971.329 4849935.028)
# 19  POINT (298916.266 4849357.908)
# 20  POINT (299970.421 4849650.476)
# 21  POINT (298384.983 4849197.293)
# 22  POINT (308594.215 4880119.863)
# 23  POINT (307909.093 4879905.731)
# 24  POINT (307038.935 4879634.275)
# 25  POINT (306373.949 4879421.963)
# 26  POINT (312404.767 4855572.646)
# 27  POINT (312977.971 4855642.245)
# 28   POINT (313504.88 4855804.792)
# 29   POINT (313924.86 4855937.017)
# 30  POINT (314266.242 4856046.293)
# 31   POINT (314610.441 4856163.66)
# 32  POINT (315749.401 4856528.949)
# 33   POINT (316146.949 4856651.04)
# 34  POINT (316698.854 4856809.556)
# 35  POINT (317720.919 4857142.609)
# 36   POINT (317893.42 4856817.436)
# 37  POINT (318358.393 4856559.208)
# 38  POINT (312173.748 4840521.145)
# 39  POINT (310799.464 4840121.862)
# 40  POINT (314699.861 4841239.959)
# 41  POINT (319824.166 4842907.523)
# 42  POINT (322691.741 4843368.952)
# 43  POINT (307652.169 4839135.686)
# 44  POINT (311459.326 4840313.578)
# 45  POINT (317781.352 4842293.236)
# 46  POINT (308810.901 4839521.838)
# 47  POINT (312968.163 4840751.953)
# 48   POINT (309959.27 4839877.276)
# 49  POINT (318176.708 4842465.367)
# Index(['LOCATION_N', 'STATUS', 'TECHNOLOGY', 'NAME', 'geometry'], dtype='object')
